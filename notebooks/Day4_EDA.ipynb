# %%
import pandas as pd
df = pd.read_csv("../data/Cleaned_Superstore.csv")

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount      Profit
# count   9977.000000   9977.000000  9977.000000  9977.000000  9977.00000
# mean   55154.964117    230.148902     3.790719     0.156278    28.69013
# std    32058.266816    623.721409     2.226657     0.206455   234.45784
# min     1040.000000      0.444000     1.000000     0.000000 -6599.97800
# 25%    23223.000000     17.300000     2.000000     0.000000     1.72620
# 50%    55901.000000     54.816000     3.000000     0.200000     8.67100
# 75%    90008.000000    209.970000     5.000000     0.200000    29.37200
# max    99301.000000  22638.480000    14.000000     0.800000  8399.97600

# %%
df["Category"].unique()
# Out:
# array(['Furniture', 'Office Supplies', 'Technology'], dtype=object)

# %%
df["Category"].value_counts()  # counts how many times each category appear
# Out:
# Category
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: count, dtype: int64

# %%
df["Region"].value_counts()    # it tells which region has most and least records
# Out:
# Region
# West       3193
# East       2845
# Central    2319
# South      1620
# Name: count, dtype: int64

# %%
df["Segment"].value_counts()
# Out:
# Segment
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: count, dtype: int64

# %%
df["Sales"].sum()    # Calculate total sales
# Out:
# np.float64(2296195.5903)

# %%
df["Profit"].sum()    # Calculate total profit
# Out:
# np.float64(286241.42260000005)

# %%
df["Sales"].mean()    # Calculate Average sales
# Out:
# np.float64(230.14890150345792)

# %%
df["Profit"].mean()      # Calculate Average profit
# Out:
# np.float64(28.690129557983365)

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9972    Second Class   Consumer  United States            Miami     Florida
# 9973  Standard Class   Consumer  United States       Costa Mesa  California
# 9974  Standard Class   Consumer  United States       Costa Mesa  California
# 9975  Standard Class   Consumer  United States       Costa Mesa  California
# 9976    Second Class   Consumer  United States      Westminster  California
#
# ...
